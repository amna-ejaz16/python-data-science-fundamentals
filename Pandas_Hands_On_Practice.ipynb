# %% [markdown]
# <a href="https://colab.research.google.com/github/amna-ejaz16/python-data-science-fundamentals/blob/main/Pandas_Hands_On_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Series

# %%
import pandas as pd
s = pd.Series([1,2,3,4,5])
print(s)
print(type(s))

print(s[0])
print(s[1])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>
# 1
# 2

# %%
s = pd.Series([10,20,30,40,50], index = ["Amna","Eman","Zainab","Maryam","Hina"])
print(s)
print(s["Amna"])
print(s["Hina"])
print(s.index)
# Out:
# Amna      10
# Eman      20
# Zainab    30
# Maryam    40
# Hina      50
# dtype: int64
# 10
# 50
# Index(['Amna', 'Eman', 'Zainab', 'Maryam', 'Hina'], dtype='object')

# %%
s = pd.Series([1,2,3,"xyz"], index = ["Amna","Eman","Zainab",25])
print(s)
# Out:
# Amna        1
# Eman        2
# Zainab      3
# 25        xyz
# dtype: object

# %%
s1 = pd.Series([1,2,3,4])
s2 = pd.Series([10,20,30,40])
print(s1+s2)

s1[0] = 99
print(s1)

changed_s1 = s1.drop(0)
print(changed_s1)

changed_s2 = s2.add(4)
print(changed_s2)
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# dtype: int64
# 0    99
# 1     2
# 2     3
# 3     4
# dtype: int64
# 1    2
# 2    3
# 3    4
# dtype: int64
# 0    14
# 1    24
# 2    34
# 3    44
# dtype: int64

# %% [markdown]
# # DataFrames

# %%
import pandas as pd
student_information = {
    "Name":["Amna","Maryam","Zainab"],
    "Age":[21,21,21],
    "Marks":[20,30,40]
}
df = pd.DataFrame(student_information)
print(df)
print(df, type(df))
print(df.index)
print(df.columns)
# Out:
#      Name  Age  Marks
# 0    Amna   21     20
# 1  Maryam   21     30
# 2  Zainab   21     40
#      Name  Age  Marks
# 0    Amna   21     20
# 1  Maryam   21     30
# 2  Zainab   21     40 <class 'pandas.core.frame.DataFrame'>
# RangeIndex(start=0, stop=3, step=1)
# Index(['Name', 'Age', 'Marks'], dtype='object')

# %%
df = pd.DataFrame([["Amna",20],["Zainab",21],["Maryam",21]], columns = ["Name","Age"])
print(df)
# Out:
#      Name  Age
# 0    Amna   20
# 1  Zainab   21
# 2  Maryam   21

# %%
import numpy as np
numpy_array = np.array([[1,2,3],[4,5,6]])
df = pd.DataFrame(numpy_array, columns = ["N1","N2","N3"])
print(df)
# Out:
#    N1  N2  N3
# 0   1   2   3
# 1   4   5   6

# %% [markdown]
# # Creating DataFrame from CSV File

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/employee_data.csv")
print(df)
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000

# %% [markdown]
# # DataFrame Methods

# %%
df = pd.read_csv("/content/drive/MyDrive/employee_data.csv")
df
print(df.head())
print(df.tail())
print(df.sample(5))
print(df.info())
print(df.describe())
print(df.nunique())

print(df.shape)
print(df.columns)
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
#    ID    Name  Age Department  Salary
# 5   6   Frank   29    Finance   50000
# 6   7   Grace   41         HR   82000
# 7   8  Hannah   26  Marketing   47000
# 8   9     Ian   35         IT   75000
# 9  10   Julia   30    Finance   60000
#    ID    Name  Age Department  Salary
# 5   6   Frank   29    Finance   50000
# 1   2     Bob   32         IT   72000
# 6   7   Grace   41         HR   82000
# 9  10   Julia   30    Finance   60000
# 7   8  Hannah   26  Marketing   47000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          10 non-null     int64
#  1   Name        10 non-null     object
# ...

# %% [markdown]
# # Indexing & Selecting Data

# %%
df = pd.read_csv("/content/drive/MyDrive/globalAirQuality.csv")
df

df["city"]
df[["city","aqi"]]

# Rows
df.loc[2]
df.loc[0:3]

df.loc[0,"pm10"]

df.iloc[2]
df.iloc[0:3]
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
# 2  2025-11-04 20:25:17.554219      US  New York    40.713    -74.006  42.250
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 1   63.043  36.120  4.021  43.536  1.075   90        5.838    80.088
# 2   82.553  26.935  9.538  23.320  0.977   84       31.833    62.783
#
#    wind_speed
# 0       3.725
# 1       8.969
# 2       9.650

# %%
df.loc[0:2, ["city","aqi"]]
df.loc[0:2, ["country","city","latitude","longitude"]]

df.iloc[0:2, 1:6]
# Out:
#   country      city  latitude  longitude    pm25
# 0      US  New York    40.713    -74.006  50.295
# 1      US  New York    40.713    -74.006  32.083

# %%
df.at[0,"city"]
df.iat[0,3]
# Out:
# np.float64(40.713)

# %% [markdown]
# # Filtering & Querying Data

# %%
df[df["aqi"] > 100]
df[(df["aqi"] > 100) & (df["temperature"] > 30)]
df[(df["aqi"] > 120) & (df["temperature"] < 30)]

aqi_data = df[(df["aqi"] >100) & (df["temperature"] > 30)] [["city","aqi"]]
aqi_data

aqi_data.iloc[0]
aqi_data.loc[6]
# Out:
# city    New York
# aqi          155
# Name: 6, dtype: object

# %%
df.query("aqi > 100 & temperature > 30") [["city","aqi"]]

aqi_value = 100
aqi_data = df.query("aqi > @aqi_value & temperature > 30")
print(aqi_data)
# Out:
#                         timestamp country      city  latitude  longitude  \
# 6      2025-11-05 00:25:17.554219      US  New York    40.713    -74.006
# 7      2025-11-05 01:25:17.554219      US  New York    40.713    -74.006
# 14     2025-11-05 08:25:17.554219      US  New York    40.713    -74.006
# 17     2025-11-05 11:25:17.554219      US  New York    40.713    -74.006
# 25     2025-11-05 19:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17947  2025-11-17 13:25:17.554219      CH    Zurich    47.377      8.542
# 17950  2025-11-17 16:25:17.554219      CH    Zurich    47.377      8.542
# 17975  2025-11-18 17:25:17.554219      CH    Zurich    47.377      8.542
# 17976  2025-11-18 18:25:17.554219      CH    Zurich    47.377      8.542
# 17991  2025-11-19 09:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %% [markdown]
# # Data Cleaning

# %%
# Handling Missing Values
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/raw_data.csv")

cleaned_data = df.copy()
age_mean = cleaned_data["age"].mean()
cleaned_data["age"] = cleaned_data["age"].fillna(age_mean)
cleaned_data
# Out:
#     id          name    age country   gender   income
# 0    1      John Doe  29.00     USA     Male  55000.0
# 1    1      John Doe  29.00     USA     Male  55000.0
# 2    2    Jane Smith  32.75  Canada   Female  62000.0
# 3    3          Alex  32.75     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.00   Spain   Female      NaN
# 5    5        Li Wei  27.00   China     Male  51000.0
# 6    6           NaN  45.00   India   Female  73000.0
# 7    7    Ahmed Khan  38.00     NaN     Male  68000.0
# 8    8    Rachel Lee  29.00     USA   Female  62000.0
# 9    9   Carlos Ruiz  32.75  Mexico     Male  45000.0
# 10  10   Emily Davis  31.00     USA      NaN  58000.0

# %%
df.ffill()
df.bfill()
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith  34.0  Canada   Female  62000.0
# 3    3          Alex  34.0     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female  51000.0
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6    Ahmed Khan  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     USA     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz  31.0  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
# Handling Duplicate Values
df.duplicated()
df.drop_duplicates()

df["gender"].duplicated()
df[["country","name"]].duplicated()

df2 = df.copy()
df2 = df2.drop_duplicates()
df2
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
df
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
# Handling Data Types
df.dtypes
df2 = df.copy()
df2 = df2.fillna(0)
df2["age"] = df2["age"].astype("int64")
df2.dtypes
# Out:
# id           int64
# name        object
# age          int64
# country     object
# gender      object
# income     float64
# dtype: object

# %%
# Converting Data into datetime
df = pd.read_csv("/content/drive/MyDrive/globalAirQuality.csv")
df2 = df.copy()
df2["timestamp"] = pd.to_datetime(df2["timestamp"])
df2.dtypes


date_str = pd.Series([pd.to_datetime("2026-12-22")])
type(date_str.dtypes)
# Out:
# numpy.dtypes.DateTime64DType

# %%
# Handling Strings
df = pd.read_csv("/content/drive/MyDrive/raw_data.csv")
df
df["country"].str.lower()
df["name"].str.split()
df["name"].str.contains("DOE", case = False)
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6       NaN
# 7     False
# 8     False
# 9     False
# 10    False
# Name: name, dtype: object

# %% [markdown]
# # Data Transformation

# %%
import pandas as pd

# apply function
df = pd.read_csv("/content/drive/MyDrive/raw_data.csv")
df

df2 = df.copy()
df2["tax"] = df["income"].apply(lambda x:"20%" if x>= 60000 else "10%")
df2
# Out:
#     id          name   age country   gender   income  tax
# 0    1      John Doe  29.0     USA     Male  55000.0  10%
# 1    1      John Doe  29.0     USA     Male  55000.0  10%
# 2    2    Jane Smith   NaN  Canada   Female  62000.0  20%
# 3    3          Alex   NaN     USA  Unknown  47000.0  10%
# 4    4  Maria Garcia  34.0   Spain   Female      NaN  10%
# 5    5        Li Wei  27.0   China     Male  51000.0  10%
# 6    6           NaN  45.0   India   Female  73000.0  20%
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0  20%
# 8    8    Rachel Lee  29.0     USA   Female  62000.0  20%
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0  10%
# 10  10   Emily Davis  31.0     USA      NaN  58000.0  10%

# %%
# map function
df = pd.read_csv("/content/drive/MyDrive/raw_data.csv")
df
df2 = df.copy()
df2

gender_map = {"Male":"M","Female":"F", "Unknown":"U" }
df2["gender"] = df2["gender"].map(gender_map)
df2
# Out:
#     id          name   age country gender   income
# 0    1      John Doe  29.0     USA      M  55000.0
# 1    1      John Doe  29.0     USA      M  55000.0
# 2    2    Jane Smith   NaN  Canada      F  62000.0
# 3    3          Alex   NaN     USA      U  47000.0
# 4    4  Maria Garcia  34.0   Spain      F      NaN
# 5    5        Li Wei  27.0   China      M  51000.0
# 6    6           NaN  45.0   India      F  73000.0
# 7    7    Ahmed Khan  38.0     NaN      M  68000.0
# 8    8    Rachel Lee  29.0     USA      F  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico      M  45000.0
# 10  10   Emily Davis  31.0     USA    NaN  58000.0

# %%
# assign function
df = pd.read_csv("/content/drive/MyDrive/raw_data.csv")
df
df2 = df.copy()
df2

df2 = df2.assign(new_income = df2['income']*1.1)
df2
# Out:
#     id          name   age country   gender   income  new_income
# 0    1      John Doe  29.0     USA     Male  55000.0     60500.0
# 1    1      John Doe  29.0     USA     Male  55000.0     60500.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0     68200.0
# 3    3          Alex   NaN     USA  Unknown  47000.0     51700.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN         NaN
# 5    5        Li Wei  27.0   China     Male  51000.0     56100.0
# 6    6           NaN  45.0   India   Female  73000.0     80300.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0     74800.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0     68200.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0     49500.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0     63800.0

# %%
# replace method
df = pd.read_csv("/content/drive/MyDrive/raw_data.csv")
df
df2 = df.copy()
df2

df2["name"] = df2["name"].replace("John Doe", "Tommy")
df2

df2["country"] = df2["country"].replace("USA","US")
df2
# Out:
#     id          name   age country   gender   income
# 0    1         Tommy  29.0      US     Male  55000.0
# 1    1         Tommy  29.0      US     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN      US  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0      US   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0      US      NaN  58000.0

# %% [markdown]
# # Some other methods of data transformation

# %%
# rename columns
df = pd.read_csv("/content/drive/MyDrive/raw_data.csv")
df
df2 = df.copy()
df2

# df2.columns = ["Id","Name","Age","Country","Gender","Income"]
# df2

# df2 = df2.rename(columns = {"income":"Salary"})
# df2

# df2 = df2.rename(index = {1:"First"})
# df2

df2 = df2.rename(columns = {"name":"full name"})
df2
# Out:
#     id     full name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
# sort values
df = pd.read_csv("/content/drive/MyDrive/raw_data.csv")
df
df2 = df.copy()
df2

# df2 = df2.fillna(99)
# df2 = df2.sort_values("income")
# df2

# df2 = df2.fillna(99)
# sorted_df = df2.sort_values(["income","age"])
# sorted_df

df2 = df2.fillna(99)
df2 = df2.sort_values("income", ascending = False)
df2
# Out:
#     id          name   age country   gender   income
# 6    6            99  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0      99     Male  68000.0
# 2    2    Jane Smith  99.0  Canada   Female  62000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 10  10   Emily Davis  31.0     USA       99  58000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 0    1      John Doe  29.0     USA     Male  55000.0
# 5    5        Li Wei  27.0   China     Male  51000.0
# 3    3          Alex  99.0     USA  Unknown  47000.0
# 9    9   Carlos Ruiz  99.0  Mexico     Male  45000.0
# 4    4  Maria Garcia  34.0   Spain   Female     99.0

# %%
# sort index
df = pd.read_csv("/content/drive/MyDrive/raw_data.csv")
df
df2 = df.copy()
df2

df2 = df2.fillna(99)
df2 = df2.sort_values("income", ascending = False)
df2

df2 = df2.sort_index()
df2
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith  99.0  Canada   Female  62000.0
# 3    3          Alex  99.0     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female     99.0
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6            99  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0      99     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz  99.0  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA       99  58000.0

# %%
# sort index
df = pd.read_csv("/content/drive/MyDrive/raw_data.csv")
df
df2 = df.copy()
df2

df2 = df2.fillna(99)
sorted_df = df2.sort_values("income")
# sorted_df

sorted_df = sorted_df.sort_index()
sorted_df
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith  99.0  Canada   Female  62000.0
# 3    3          Alex  99.0     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female     99.0
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6            99  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0      99     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz  99.0  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA       99  58000.0

# %%
# reset index
df = pd.read_csv("/content/drive/MyDrive/raw_data.csv")
df
df2 = df.copy()
df2

df2 = df2.fillna(99)
sorted_df = df2.sort_values("income")
sorted_df

sorted_df = sorted_df.reset_index(drop = True)
sorted_df
# Out:
#     id          name   age country   gender   income
# 0    4  Maria Garcia  34.0   Spain   Female     99.0
# 1    9   Carlos Ruiz  99.0  Mexico     Male  45000.0
# 2    3          Alex  99.0     USA  Unknown  47000.0
# 3    5        Li Wei  27.0   China     Male  51000.0
# 4    1      John Doe  29.0     USA     Male  55000.0
# 5    1      John Doe  29.0     USA     Male  55000.0
# 6   10   Emily Davis  31.0     USA       99  58000.0
# 7    2    Jane Smith  99.0  Canada   Female  62000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    7    Ahmed Khan  38.0      99     Male  68000.0
# 10   6            99  45.0   India   Female  73000.0

# %%
# rank data
sorted_df["Ranking"] = sorted_df["income"].rank()
sorted_df

sorted_df["Ranking"] = sorted_df["income"].rank(ascending = False, method = "max")
sorted_df

# re-order columns
sorted_df[["id","name","country","gender","Ranking","income","age"]]
sorted_df
# Out:
#     id          name   age country   gender   income  Ranking
# 0    4  Maria Garcia  34.0   Spain   Female     99.0     11.0
# 1    9   Carlos Ruiz  99.0  Mexico     Male  45000.0     10.0
# 2    3          Alex  99.0     USA  Unknown  47000.0      9.0
# 3    5        Li Wei  27.0   China     Male  51000.0      8.0
# 4    1      John Doe  29.0     USA     Male  55000.0      7.0
# 5    1      John Doe  29.0     USA     Male  55000.0      7.0
# 6   10   Emily Davis  31.0     USA       99  58000.0      5.0
# 7    2    Jane Smith  99.0  Canada   Female  62000.0      4.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0      4.0
# 9    7    Ahmed Khan  38.0      99     Male  68000.0      2.0
# 10   6            99  45.0   India   Female  73000.0      1.0

# %%
df = pd.read_csv("/content/drive/MyDrive/raw_data.csv")
df
df2 = df.copy()
df2

new_col_order = [col for col in df2.columns if col != "id"] + ["id"]
new_col_order

df2 = df2[new_col_order]
df2
# Out:
#             name   age country   gender   income  id
# 0       John Doe  29.0     USA     Male  55000.0   1
# 1       John Doe  29.0     USA     Male  55000.0   1
# 2     Jane Smith   NaN  Canada   Female  62000.0   2
# 3           Alex   NaN     USA  Unknown  47000.0   3
# 4   Maria Garcia  34.0   Spain   Female      NaN   4
# 5         Li Wei  27.0   China     Male  51000.0   5
# 6            NaN  45.0   India   Female  73000.0   6
# 7     Ahmed Khan  38.0     NaN     Male  68000.0   7
# 8     Rachel Lee  29.0     USA   Female  62000.0   8
# 9    Carlos Ruiz   NaN  Mexico     Male  45000.0   9
# 10   Emily Davis  31.0     USA      NaN  58000.0  10

# %% [markdown]
# # Writing Data to csv and json files

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/raw_data.csv")
df

df2 = df.copy()
df2 = df2.drop_duplicates()
df2 = df2.fillna(0)
df2

df2 = df2.sort_values("income")
df2

df2 = df2.reset_index(drop = True)
df2

df2.to_csv("sorted_data.csv")
df2.to_json("sorted_data1.json")

# %% [markdown]
# # Grouping & Aggregation Methods

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/raw_data.csv")
df

df2 = df.copy()
df2 = df2.drop_duplicates()

df2

# df2 = df2.groupby("country")["income"].mean()
# df2

# df2 = df2.groupby("country")["income"].min()
# df2

# df2 = df2.groupby("gender")["income"].max()
# df2

# df2 = df2.groupby("country")["gender"].count()
# df2
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
df2
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   0.0  Canada   Female  62000.0
# 3    3          Alex   0.0     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      0.0
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6             0  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0       0     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   0.0  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA        0  58000.0

# %%
# df2 = df2.groupby("country")["income"].aggregate(["mean","max","min"])
# df2

# df2 = df2.groupby("country")["income"].agg(avg_salary = "mean", max_salary = "max", min_salary = "min" )
# df2

# df2 = df2.groupby("country").agg({
#     "income":"mean",
#     "age":"mean"
# })
# df2

# renaming columns
df2 = df2.groupby("country").agg(
    max_salary = ("income","max"),
    mean_age = ("age", "mean")
)

df2
# Out:
#          max_salary   mean_age
# country
# Canada      62000.0        NaN
# China       51000.0  27.000000
# India       73000.0  45.000000
# Mexico      45000.0        NaN
# Spain           NaN  34.000000
# USA         62000.0  29.666667

# %% [markdown]
# # Reshaping Methods

# %%
import pandas as pd
df = pd.DataFrame({
    "country": ["India","India","USA","USA"],
    "year": [2020,2021,2020,2021],
    "sales": [100,120,90,110],
    "profit": [20,25,18,22],
})
df
# Out:
#   country  year  sales  profit
# 0   India  2020    100      20
# 1   India  2021    120      25
# 2     USA  2020     90      18
# 3     USA  2021    110      22

# %%
melted_df = df.melt(
    id_vars = ["country","year"],
    value_vars = ["sales","profit"],
    var_name = "metrics",
    value_name = "value"
)
melted_df

original_df = melted_df.pivot(
    index = ["country","year"],
    columns = "metrics",
    values = "value"
)
original_df
# Out:
# metrics       profit  sales
# country year
# India   2020      20    100
#         2021      25    120
# USA     2020      18     90
#         2021      22    110

# %% [markdown]
# # Basic Visualization

# %%
df = pd.read_csv("/content/drive/MyDrive/employee_data.csv")
df
df["Age"].hist()

df.plot(kind="scatter", x="Age", y="Salary")
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
df
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000

# %% [markdown]
# # Combining & Joining Methods

# %%
df_customers = pd.DataFrame({
    "customer_id":[1,2,3,4],
    "name":["Amna","Eman","Zainab","Maryam"]
})

df_orders = pd.DataFrame({
    "order_id":[101,102,103,104],
    "customer_id":[1,2,3,5],
    "amount":[250,100,300,160]
})

pd.merge(df_customers,df_orders, on="customer_id")
pd.merge(df_customers,df_orders, on="customer_id", how="left")
pd.merge(df_customers,df_orders, on="customer_id", how="right")
pd.merge(df_customers,df_orders, on="customer_id", how="outer")
# Out:
#    customer_id    name  order_id  amount
# 0            1    Amna     101.0   250.0
# 1            2    Eman     102.0   100.0
# 2            3  Zainab     103.0   300.0
# 3            4  Maryam       NaN     NaN
# 4            5     NaN     104.0   160.0

# %%
df_customers
# Out:
#    customer_id    name
# 0            1    Amna
# 1            2    Eman
# 2            3  Zainab
# 3            4  Maryam

# %%
df_orders
# Out:
#    order_id  customer_id  amount
# 0       101            1     250
# 1       102            2     100
# 2       103            3     300
# 3       104            5     160

# %% [markdown]
# # Data Concatenation

# %%
df1 = pd.DataFrame({
    "id":[1,2,3],
    "name": ["Amna","Eman","Zainab"]
})
df1

df2 = pd.DataFrame({
    "id":[4,5,6],
    "name":["Areeha","Hina","Maryam"]
})
df2

pd.concat([df1,df2], ignore_index=True)

pd.concat([df1,df2], axis=1)
# Out:
#    id    name  id    name
# 0   1    Amna   4  Areeha
# 1   2    Eman   5    Hina
# 2   3  Zainab   6  Maryam

# %%
# PANDAS ASSIGNMENT PROBLEMS
# QUESTION:01
df = pd.read_csv("/content/drive/MyDrive/Iris Flower Dataset.zip")
df

df.head(10)
df.shape
df.dtypes
df.describe()

df2 = df.copy()
df2

# df3 = df2[(df2["petal_length"]>4.5) & (df2["species"] =="Iris-virginica")]
# df3

# df2.groupby("species").aggregate({
#     "sepal_length" : "mean",
#     "petal_width" : "max",
#     "sepal_width" : "std"
# })

df2["petal_ratio"] = df2["petal_length"]/df2["petal_width"]
df2.groupby("species")["petal_ratio"].mean()
# Out:
# species
# Iris-setosa        7.078000
# Iris-versicolor    3.242837
# Iris-virginica     2.780662
# Name: petal_ratio, dtype: float64

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# QUESTION:02
df = pd.read_csv("/content/drive/MyDrive/Titanic_Dataset.zip")
df

# df1 = ["Name", "Sex", "Age", "Fare", "Survived"]
# df1

# df[df1].head()

df2 = df.copy()
df2

# df3 = df2[(df2["Sex"]=="female") & (df2["Fare"]>30)]
# df3


# df2.groupby("Pclass").agg({
#     "Survived":"mean",
#     "Fare":"mean",
#     "Age":"mean"
# })
# Out:
#         Survived       Fare        Age
# Pclass
# 1       0.629630  84.154687  38.233441
# 2       0.472826  20.662183  29.877630
# 3       0.242363  13.675550  25.140620

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
